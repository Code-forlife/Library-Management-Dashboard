# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("student.db")

# Load student data from SQLite database
student_data = pd.read_sql_query("SELECT * FROM students", conn)

# Close the database connection
conn.close()

# %%
student_data
# Out:
#              Date      ID      Type  \
# 0      2024-04-21  I20543    Return
# 1      2024-04-21  I20543  Fine Due
# 2      2024-04-21  I20543     Issue
# 3      2024-04-14  I30982     Issue
# 4      2024-04-14  I50983     Issue
# ...           ...     ...       ...
# 22434  2024-03-28  E16967    Return
# 22435  2024-03-28  E19438    Return
# 22436  2024-03-28  E16963    Return
# 22437  2024-03-19  E21751     Issue
# 22438  2024-03-19  E17019     Issue
#
#                                                Title  Fine  \
# 0                     Data Structures and Algorithms  50.0
# 1                     Data Structures and Algorithms  50.0
# 2                     Data Structures and Algorithms   0.0
# 3      Machine Learning: A Probabilistic Perspective   0.0
# 4                                      Deep Learning   0.0
# ...                                              ...   ...
# 22434                                          Hindu   0.0
# 22435                          Panipatcha Ransangram   0.0
# 22436                           Marathyancha Etihaas   0.0
# 22437                           Communication skills   0.0
# 22438                           Communication Skills   0.0
#
#                             author                                 Name  \
# 0                         Peterson                           SAHIL SHAH
# 1                         Peterson                           SAHIL SHAH
# 2                         Peterson                           SAHIL SHAH
# 3                 Murphy, Kevin P.                       PRANAY SINGHVI
# 4                       Goodfellow                       PRANAY SINGHVI
# ...                            ...                                  ...
# 22434           Nemade Bhalchandra  Ravindra Ravindra Ramchandra Rathod
# 22435  Shevde, Satchidanand Suresh  Ravindra Ravindra Ramchandra Rathod
# 22436                Biradar T. K.  Ravindra Ravindra Ramchandra Rathod
# 22437              Mathew, Shirley   Somyavandit Ms. Saomyavandit S. A.
# 22438              Raman Meenakshi   Somyavandit Ms. Saomyavandit S. A.
#
#               UID                      Email
# 0      2021300115      sahil.shah@spit.ac.in
# 1      2021300115      sahil.shah@spit.ac.in
# 2      2021300115      sahil.shah@spit.ac.in
# 3      2021300126  pranay.singhvi@spit.ac.in
# 4      2021300126  pranay.singhvi@spit.ac.in
# ...           ...                        ...
# 22434       U0900
# 22435       U0900
# 22436       U0900
# 22437       U0901
# 22438       U0901
#
# [22439 rows x 9 columns]
